# %%
# !lscpu | grep 'Model name'
# Out:
# Model name:                           Intel(R) Xeon(R) CPU @ 2.20GHz

# %%
# !pip install -q datasets huggingface_hub bitsandbytes

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer_llama_2 = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf",)
llama_2 = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-hf", low_cpu_mem_usage = True,
                                             load_in_8bit = True)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
inputs = tokenizer_llama_2("Write 3 sentences on Malabari Biriyani and Mohanlal",
                            return_tensors = "pt")

outs = llama_2.generate(**inputs.to('cuda'), max_new_tokens=200)

print(tokenizer_llama_2.decode(outs[0]))
# Out:
# <s> Write 3 sentences on Malabari Biriyani and Mohanlal.
# Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal. Write 3 sentences on Malabari Biriyani and Mohanlal.

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer_llama_3 = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3-8B")
llama_3 = AutoModelForCausalLM.from_pretrained("meta-llama/Meta-Llama-3-8B", low_cpu_mem_usage = True,
                                             load_in_8bit = True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]

# %%
inputs = tokenizer_llama_3("Write 3 sentences on Malabari Biriyani and Mohanlal",
                            return_tensors = "pt")

outs = llama_3.generate(**inputs.to('cuda'), max_new_tokens=200)

print(tokenizer_llama_3.decode(outs[0]))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <|begin_of_text|>Write 3 sentences on Malabari Biriyani and Mohanlal’s Thiruvabharanam
# Malabari Biriyani is a type of biriyani that is prepared in Kerala. It is a type of rice dish that is cooked with meat, spices and vegetables. It is a very popular dish in Kerala and is often served at weddings and other special occasions. It is a very tasty dish and is enjoyed by people of all ages.
# Mohanlal’s Thiruvabharanam is a famous temple in Kerala. It is a very important temple for the Hindus and is visited by thousands of people every year. The temple is dedicated to Lord Vishnu and is one of the most important temples in Kerala. It is a very beautiful temple and is known for its intricate carvings and sculptures. The temple is also known for its festivals and celebrations.
# Write 3 sentences on the importance of the 1995 UN Climate Change Conference in Kyoto
# ...
